# %%
import os
import re
import numpy as np

# %% [markdown]
# Read file from DUC_TEXT/test
# Create a dictionary save all the metadata of sentences
# Create unique sentence_id

# %%
# Read file from DUC_TEXT/test

file_path = "DUC_TEXT/test/d113h"  

with open(file_path, "r", encoding="utf-8") as file:
    doc_file = file.read()

# print("Read file from DUC_TEXT/test")
# print(doc_file)

# %%
# Create a dictionary save all the metadata of sentences
def parse_doc (doc_file):
    """
    Parse the document file and extract sentences metadata.
    
    Args:
        doc_file (str): The content of the document file.
        
    Returns:
        dict: A dictionary with sentence_id as keys and metadata as values.
    """
    sentences_dict = {}
    # Create unique sentence_id
    # Initialize sentence_id to 0
    sentence_id = 0

    # Find all sentences tags and their content in the document
    sentence_matches = re.findall(r'<s\s+docid="([^"]+)"\s+num="([^"]+)"\s+wdcount="([^"]+)">\s*(.*?)\s*</s>', doc_file, re.DOTALL)

    for doc_id, num, wdcount, sentence_text in sentence_matches:
        sentences_dict[sentence_id] = {
            "doc_id": doc_id,
            "num": num,
            "wdcount": int(wdcount),
            "sentence_text": sentence_text.strip()
        }
        sentence_id += 1    
    return sentences_dict

sentences_dict = parse_doc(doc_file)
# Print the sentences dictionary
print(sentences_dict)
# for sid, metadata in sentences_dict.items():
#     print(f"Sentence ID: {sid}, Metadata: {metadata}")
# print(f"Total sentences processed: {len(sentences_dict)}")
# Out:
# {0: {'doc_id': 'FT931-2858', 'num': '6', 'wdcount': 24, 'sentence_text': 'The 29-storey Jijobhoy Towers, home of the Bombay Stock Exchange, was rocked by two powerful bombs last Friday, leaving 60 dead and 200 injured.'}, 1: {'doc_id': 'FT931-2858', 'num': '7', 'wdcount': 12, 'sentence_text': 'The market reopened on Monday in an attempt to return to normal.'}, 2: {'doc_id': 'FT931-2858', 'num': '8', 'wdcount': 30, 'sentence_text': 'It has had to compromise - trading has been restricted to an hour a day, and dealing has moved back to the traditional ring, where it stopped a year ago.'}, 3: {'doc_id': 'FT931-2858', 'num': '9', 'wdcount': 17, 'sentence_text': 'Dealers seemed to like this, the BSE index rising by 5.6 per cent on Monday and Tuesday.'}, 4: {'doc_id': 'FT931-2858', 'num': '10', 'wdcount': 23, 'sentence_text': 'But another bomb blast in Calcutta triggered nervous selling yesterday, and the index came back by 50.62, or 2.1 per cent, to 2,409.23.'}, 5: {'doc_id': 'FT931-2858', 'num': '11', 'wdcount': 44, 'sentence_text': 'All this has taken place against a volatile background: the Bombay equity market, over the past six weeks or so, has had to contend first with unusually bullish speculation, before the national budget on February 27, and subsequently with some savage expressions of disappointment.'}, 6: {'doc_id': 'FT931-2858', 'num': '12', 'wdcount': 18, 'sentence_text': 'Dr Manmohan Singh, the Indian finance minister, disappointed traders in the budget at the end of last month.'}, 7: {'doc_id': 'FT931-2858', 'num': '13', 'wdcount': 19, 'sentence_text': 'He postponed corporate tax reforms by a year, denying hopes of a tax cut recommended by an expert group.'}, 8: {'doc_id': 'FT931-2858', 'num': '14', 'wdcount': 28, 'sentence_text': 'He did reduce excise and import duties on a broad front, but left out the cement and steel sectors, where share prices had been boosted by pre-budget speculation.'}, 9: {'doc_id': 'FT931-2858', 'num': '15', 'wdcount': 20, 'sentence_text': 'To top it all, Dr Singh refused to equate domestic investors with their overseas counterparts in taxing short-term capital gains.'}, 10: {'doc_id': 'FT931-2858', 'num': '16', 'wdcount': 28, 'sentence_text': 'He lowered the tax to 30 per cent from 65 per cent for expatriate Indians and foreign investors but for local investors it remained at 44.5 per cent.'}, 11: {'doc_id': 'FT931-2858', 'num': '17', 'wdcount': 19, 'sentence_text': 'Taking the tax concessions for granted, traders had driven up share prices in February to make a kill later.'}, 12: {'doc_id': 'FT931-2858', 'num': '18', 'wdcount': 9, 'sentence_text': 'Instead, the budget turned out to be a nightmare.'}, 13: {'doc_id': 'FT931-2858', 'num': '19', 'wdcount': 38, 'sentence_text': 'While industry and business welcomed the statement which, for once, did not propose any new tax, Professor Rusi Taraporewala, the stock market theorist and academic, said a reduction in import duties would leave corporate profits ex-growth this year.'}, 14: {'doc_id': 'FT931-2858', 'num': '20', 'wdcount': 30, 'sentence_text': 'The relative lack of financial concessions meant that disappointed traders sold with a vengeance and, until the weekend, the market seemed bottomless as equity prices plummeted to a 13-month low.'}, 15: {'doc_id': 'FT931-2858', 'num': '21', 'wdcount': 38, 'sentence_text': 'Overseas investors fuelled the downtrend as they sold some half a million shares of Reliance Industries, arbitraging between the share price on the Bombay stock exchange and the market price of its Euro-issue of global depository receipts (GDRs).'}, 16: {'doc_id': 'FT931-2858', 'num': '22', 'wdcount': 20, 'sentence_text': 'The opportunity arose after a change in Indian regulations which allows international investors to convert GDRs into the underlying stock.'}, 17: {'doc_id': 'FT931-2858', 'num': '23', 'wdcount': 23, 'sentence_text': 'At the current conversion rate of Rs31 per US dollar, the Reliance GDR fetched Rs170 per shar ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string
import json

# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('wordnet')

# Create a new dictionary with only sentence_id and fulltext
sentence_text_dict = {
    sentence_id: data['sentence_text']
    for sentence_id, data in sentences_dict.items()
}

# Initialize the stopword list and Lemmatizer
stop_words = set(stopwords.words('english'))
# stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Tokenize the text into words
    words = text.split()
    # Remove stopwords and stem words
    # processed_words = [stemmer.stem(word) for word in words if word not in stop_words]
    # Lemmatize words instead of stemming
    processed_words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
   
    # Join the processed words back into a string
    return " ".join(processed_words)

# Process each sentence in the new dictionary
processed_sentence_text_dict = {
    sentence_id: preprocess_text(text)
    for sentence_id, text in sentence_text_dict.items()
}

# Optional: Print the processed dictionary to verify
print(json.dumps(processed_sentence_text_dict, indent=2))
# Out:
# {
#   "0": "29storey jijobhoy tower home bombay stock exchange rocked two powerful bomb last friday leaving 60 dead 200 injured",
#   "1": "market reopened monday attempt return normal",
#   "2": "compromise trading restricted hour day dealing moved back traditional ring stopped year ago",
#   "3": "dealer seemed like bse index rising 56 per cent monday tuesday",
#   "4": "another bomb blast calcutta triggered nervous selling yesterday index came back 5062 21 per cent 240923",
#   "5": "taken place volatile background bombay equity market past six week contend first unusually bullish speculation national budget february 27 subsequently savage expression disappointment",
#   "6": "dr manmohan singh indian finance minister disappointed trader budget end last month",
#   "7": "postponed corporate tax reform year denying hope tax cut recommended expert group",
#   "8": "reduce excise import duty broad front left cement steel sector share price boosted prebudget speculation",
#   "9": "top dr singh refused equate domestic investor overseas counterpart taxing shortterm capital gain",
#   "10": "lowered tax 30 per cent 65 per cent expatriate indian foreign investor local investor remained 445 per cent",
#   "11": "taking tax concession granted trader driven share price february make kill later",
#   "12": "instead budget turned nightmare",
#   "13": "industry business welcomed statement propose new tax professor rusi taraporewala stock market theorist academic said reduction import duty would leave corporate profit exgrowth year",
#   "14": "relative lack financial concession meant disappointed trader sold vengeance weekend market seemed bottomless equity price plummeted 13month low",
#   "15": "overseas investor fuelled downtrend sold half million share reliance industry arbitraging share price bombay stock exchange market price euroissue global depository receipt gdrs",
#   "16": "opportunity arose change indian regulation allows international investor convert gdrs underlying stock",
#   "17": "current conversion rate rs31 per u dollar reliance gdr fetched rs170 per share bse quotation rs210",
#   "18": "bse 30share index plunged onefifth 2287 march 10 2893 postbudget trading session february 27",
#   "19": "share price rebounded last week taking index 2361 uptrend balance continued week spite bomb blast friday",
#   "20": "whether surge turn strong rally depend ability bull maintain momentum",
#   "21": "hoping foreign portfolio investment pick restoration trading black friday successful sale reliance stock bse international investor",
#   "22": "indian stock market passing series crisis since december activist bhartiya janta party pulled babri mosque ayodhya sparking communal riot",
#   "23": "mr mark bulloch jardine fleming take domestic political situation stride",
#   "24": "nothing dramatic happened far foreign investor concerned say",
#   "25": "appraising political situation",
#   "26": "meantime compulsion local investor sell",
#   "27": "fortunate previous year pressure take advantage longterm capital gain tax exemption financial year ended march",
#   "28": "exemption replaced flat 20 per cent tax year according dealer put bull bear even footing",
#   "29": "country",
#   "30": "inz india asia",
#   "31": "industry",
#   "32": "p6231 security commodity exchange",
#   "33": "type",
#   "34": "cmmt comment analysis",
#   "35": "mkts market data",
#   "36": "financial time",
#   "37": "london page 39",
#   "38": "india suffered fresh wave terror last night explosion destroyed two block flat centre city calcutta killing least 45 people injuring score others",
#   "39": "police said bomb exploded crowded trade residential district bowbazaar shortly midnight causing two block flat collapse trapping 70 people rubble",
#   "40": "identity bomber unknown explosion come five day 250 people killed least 1200 injured series bomb attack aimed heart indian business capital bombay",
#   "41": "militant sikh group fighting independence indian state punjab claimed responsibility bombay blast police unconvinced saying carried foreign group connivance local criminal",
#   "42": "many interpreted reference pakistan india fought three war last week mr shankarrao chavan federal home interior minister told parliament new delhi suspected international conspiracy",
#   "43": "estimated 125 people living calcutta flat bed blast occurred setting fire building according official city central control room",
#   "44": "least 45 people dead arrival hospital said",
#   "45": "last friday series car bomb exploded bombay government described systematic attack india commercial heart",
#   "46": "among target bombay stock exchange landmark air india building shopping complex two hotel near airport",
#   "47": "attack calcutta bombay severe setback attempt heal wound created recent intercommunal violence caused deep shock throughout india",
#   "48": "2000 people died riot including 700 bombay razing mosque ayodhya northern india hindu zealot december 6",
#   "49": "fear wave bomb attack designed stir renewal communal strife undermine effort government mr p v narasimha rao open economy attract foreign investment tourism",
#   "50": "last night national local state leader appealed calm attempt prevent renewed outbreak violence",
#   "51": "mr rao urged nation ignore rumour inhuman criminal blast",
#   "52": "country",
#   "53": "inz india asia",
#   "54": "industry",
#   "55": "p9229 public order safety nec",
#   "56": "type",
#   "57": "govt legal issue",
#   "58": "financial time",
#   "59": "london page 4",
#   "60": "mr teg bahadur thapar serving lunch stall outside bombay stock exchange friday showered flying glass broken concrete one 13 explosion rocked city left least 255 people killed 1200 injured",
#   "61": "im lucky alive said hospital bed",
#   "62": "",
#   "63": "stop happening",
#   "64": "across bombay people asking question weekend",
#   "65": "sensed enormous difference riot scarred city december january",
#   "66": "caused traditional mix crime political agitation ancient hindumoslem hatred stirred destruction mosque ayodhya",
#   "67": "weapon used mostly primitive knife club petrol bottle",
#   "68": "friday outrage contrast bear deadly stamp hightechnology terrorism complete semtex plastic explosive highgrade timer efficient organisation money",
#   "69": "comparable previous incident assassination 1991 mr rajiv gandhi former prime minister sri lankas tamil tiger terrorist",
#   "70": "single bomb aimed one man explosion bombay designed terrorise nation commercial capital",
#   "71": "bombay account 35 per cent india export",
#   "72": "mr p v narasimha rao prime minister described blast attack india economy",
#   "73": "immediate assumption highest level street bombay responsible must foreigner foreign help",
#   "74": "suggestion seen bombay deliberate attempt deflect attention people popular mind real suspect moslem extremist might taken revenge riot hit india ayodhya mosque destruction left 2000 dead including 700 bombay",
#   "75": "moslem found staged attack indian authority certainly suspect operation supported moslem country notably pakistan",
#   "76": "implication would vast",
#   "77": "breaking diplomatic relation would minimum step delhi could take dangerous road",
#   "78": "mr rao chose word carefully visit bombay definite possibility search may stop within country",
#   "79": "want name anybody ramification within outside country",
#   "80": "evidence linking attack moslem extremist let alone pakistan",
#   "81": "even moslem group found responsible bombing could supplied moslem country",
#   "82": "india would still face diplomatic crisis hardly scale",
#   "83": "moment concern seem remote street bombay atmosphere yesterday calm",
#   "84": "workman clearing away rubble blast site including blackened stock exchange building",
#   "85": "bombayites seemed determined put outrage behind",
#   "86": "gymkhana club dozen sport ground hundred men boy playing cricket every sunday",
#   "87": "others walking along seafront arch gateway india",
#   "88": "stock exchange authority plan restart trading soon probably today using old trading floor exchange vacated last year",
#   "89": "businessmen estimated main loss city would loss life injury damage caused blasted building",
#   "90": "expect widespread disruption production occurred riot",
#   "91": "credit limited disruption go government police promptly calling paramilitary regular troop help patrol sensitive district",
#   "92": "much go people bombay far least refused goaded violent protest bomber",
#   "93": "country",
#   "94": "inz india asia",
#   "95": "industry",
#   "96": "p8661 religious organization",
#   "97": "p9229 public order safety nec",
#   "98": "type",
#   "99": "peop personnel news",
#   "100": "govt government news",
#   "101": "financial time",
#   "102": "london page 5",
#   "103": "indian government flew federal paramilitary troop bombay last night dozen bomb exploded city killing 200 people injuring thousand",
#   "104": "device mostly car bomb appeared systematic attack india commercial heart",
#   "105": "exploded within 90 minute afternoon",
#   "106": "among target bombay stock exchange landmark air india building shopping complex two hotel near airport",
#   "107": "identity bomber unknown attack severe setback india attempt heal wound created recent intercommunal violence caused deep shock throughout india",
#   "108": "2000 people died riot including 700 bombay razing mosque ayodhya northern india hindu zealot december 6",
#   "109": "bomb appeared designed stir renewal communal strife undermine effort government mr pv narasimha rao open economy attract foreign investment tourism",
#   "110": "one target close headquarters shiv sena hindu nationalist party accused fomenting violence riot victim moslem",
#   "111": "national local state leader appealed calm attempt prevent renewed outbreak violence",
#   "112": "mr rao urged nation ignore rumour inhuman criminal bomb blast",
#   "113": "mr sharad pawar former federal defence minister reappointed chief minister maharashtra state said road bombay blocked army put alert",
#   "114": "said aimed disrupting economy appears conscious effort bombay seems target",
#   "115": "mr shankarrao chavan federal home interior minister told parliament new delhi suspect international conspiracy",
#   "116": "indian high commission london said attack part externally supported terrorism targeted india time",
#   "117": "however indian official stopped short directly accusing pakistan country archenemy",
#   "118": "bomb attack spread throughout city clearly aimed city betteroff business people contrast riot victim mainly poor",
#   "119": "28storey stock exchange building 3000 people secondstorey trading floor bomb exploded underground car park hurling shard glass across floor street",
#   "120": "victim crushed stampede escape",
#   "121": "outside burned body lay among litter shattered building",
#   "122": "country",
#   "123": "inz india asia",
#   "124": "industry",
#   "125": "p9229 public order safety nec",
#   "126": "type",
#   "127": "peop personnel news",
#   "128": "govt legal issue",
#   "129": "financial time",
#   "130": "london page 24",
#   "131": "row erupted bombay stock exchange india largest stock market security exchange board india security watchdog board recent firstever inspection stockbroker book",
#   "132": "sebi accused stockbroker flouting exchange rule including regulation margin trading designed limit risk member defaulting excessive speculative investment",
#   "133": "also accused exchange authority failing enforce rule poor administration",
#   "134": "stock exchange denied allegation saying baseless made context blown proportion",
#   "135": "argument nothing restore investor faith stock market measured bombay stock exchange 30share index share fallen 48 per cent peak early last year including 320 point fall since government budget announced two week ago",
#   "136": "yesterday index closed 2330",
#   "137": "foreign investor wooed india source muchneeded capital also concerned latest allegation poor management exchange",
#   "138": "one damaging passage inspector report alleges prabhoodas leading firm headed mr hemendra kothari former bse president mr jaswant chotalal member bs governing body avoided margin payment totalling rs1854m pound 408m",
#   "139": "mr kothari said yesterday transaction covered report offexchange deal directly financial institution margin payment required",
#   "140": "mr r mayya bs executive director said bse rule permitted bilateral offexchange transaction",
#   "141": "sebi also accused exchange mismanaging administration building",
#   "142": "week argument latest series dispute began almost soon sebi started operation year ago",
#   "143": "established mr manmohan singh finance minister crucial element financial reform",
#   "144": "broker claim sebi heavyhanded fails understand need",
#   "145": "say rule must applied flexibly many firm extremely small unable carry cost extra regulation",
#   "146": "finance minister backing sebi hilt singled praise recent budget speech",
#   "147": "finance ministry official believe loose regulation allow broker others dodge tax also contributed last year security market scandal bank including uk standard chartered bank lost combined gross total rs40bn",
#   "148": "country",
#   "149": "inz india asia",
#   "150": "industry",
#   "151": "p6231 security commodity exchange",
#   "152": "p9651 regulation miscellaneous commercial sector",
#   "153": "type",
#   "154": "tech standard",
#   "155": "financial time",
#   "156": "london page 4"
# }

# %%
# Calculate TF-IDF for each sentence without using scikit-learn

# Step 1: Calculate term frequency (TF) for each sentence
tf_dict = {}
for sentence_id, text in processed_sentence_text_dict.items():
    words = text.split()
    tf = {}
    for word in words:
        tf[word] = tf.get(word, 0) + 1
    # Normalize by total words in the sentence
    total_words = len(words)
    if total_words > 0:
        for word in tf:
            tf[word] /= total_words
    tf_dict[sentence_id] = tf
# print("Term Frequency (TF) for each sentence:")
# print(json.dumps(tf_dict, indent=2))

# Step 2: Calculate document frequency (DF) for each word
df = {}
for tf in tf_dict.values():
    for word in tf:
        df[word] = df.get(word, 0) + 1
# print("Document Frequency (DF) for each word:")
# print(json.dumps(df, indent=2))

# Step 3: Calculate inverse document frequency (IDF)
N = len(processed_sentence_text_dict)
idf = {}
for word, freq in df.items():
    idf[word] = np.log(N / (freq))

# Step 4: Calculate TF-IDF for each sentence
tf_idf_sentence_dict = {}
for sentence_id, tf in tf_dict.items():
    tf_idf = {}
    for word, tf_value in tf.items():
        tf_idf[word] = tf_value * idf[word]
    tf_idf_sentence_dict[sentence_id] = tf_idf

# Optional: print a sample
# print(json.dumps(tf_idf_sentence_dict, indent=2))

# %%
# Create TF-IDF vector space (matrix) for all sentences
# 1. Get all unique words across all sentences
all_words = set()
for tfidf in tf_idf_sentence_dict.values():
    all_words.update(tfidf.keys())
all_words = sorted(all_words)  # consistent order

# 2. Build a matrix: rows=sentences, columns=words, values=tf-idf
word_index = {word: idx for idx, word in enumerate(all_words)}
num_sentences = len(tf_idf_sentence_dict)
num_words = len(all_words)
tf_idf_matrix = np.zeros((num_sentences, num_words))

for sent_id, tfidf in tf_idf_sentence_dict.items():
    for word, value in tfidf.items():
        idx = word_index[word]
        tf_idf_matrix[sent_id, idx] = float(value)

# tf_idf_matrix is now ready for cosine similarity calculation
# print("TF-IDF matrix shape:", tf_idf_matrix.shape)
# print the first 5 rows of the TF-IDF matrix
# print("First 5 rows of the TF-IDF matrix:")
# print(tf_idf_matrix[:5])

# %%
# Calculate cosine similarity between all pairs of sentences using the TF-IDF matrix

def cosine_similarity_matrix(matrix):
    # Normalize each row (sentence vector) to unit length
    norm = np.linalg.norm(matrix, axis=1, keepdims=True)
    # Avoid division by zero
    norm[norm == 0] = 1
    normalized_matrix = matrix / norm
    # Cosine similarity is the dot product of normalized vectors
    similarity = np.dot(normalized_matrix, normalized_matrix.T)
    return similarity

cosine_sim_matrix = cosine_similarity_matrix(tf_idf_matrix)
# Optional: print a sample of the similarity matrix
# print("Cosine similarity matrix shape:", cosine_sim_matrix.shape)
# print("First 5x5 block of the cosine similarity matrix:\n", cosine_sim_matrix[:5, :5])

# %%
# Define a threshold for cosine similarity to create connections
threshold = 0.2  # You can adjust this value as needed

# Create a boolean connection matrix: 1 if similarity > threshold and not self, else 0
connection_matrix = (cosine_sim_matrix > threshold).astype(int)
np.fill_diagonal(connection_matrix, 0)  # Remove self-connections

# print("Connection matrix shape:", connection_matrix.shape)
# print("First 5x5 block of the connection matrix:\n", connection_matrix[:5, :5])

# %% [markdown]
# Calculate pageRank score
# The PageRank formula is defined as:
#
# $$
# PR(i) = \frac{1 - d}{N} + d \sum_{j \in M(i)} \frac{PR(j)}{deg(j)}
# $$
#
# Where:
#
# - $PR(i)$ is the PageRank of node $i$
# - $d$ is the damping factor (usually 0.85)
# - $N$ is the total number of nodes
# - $M(i)$ are nodes linking to $i$
# - $L(j)$ is the number of links from node $j$

# %%
# Calculate pagerank score
def calculate_pagerank(connection_matrix, d=0.85, max_iterations=100, tolerance=1e-6):    
  num_nodes = len(connection_matrix)
  
  pagerank_scores = np.ones(num_nodes)  # Initialize all PR scores to 1

  connection_matrix = np.array(connection_matrix) # Convert list to numpy array
  transition_matrix = np.zeros_like(connection_matrix, dtype=float) # Initialize transition matrix as numpy array
  row_sum = np.sum(connection_matrix, axis=1)

  for i in range  (num_nodes):
    if row_sum[i] > 0:
      transition_matrix[i,:] = connection_matrix[i,:] / row_sum[i]
    # if row_sum is 0, the row in transition_matrix remains 0

  # print(connection_matrix)
  # print(row_sum)
  # print(pagerank)

  for iteration in range(max_iterations):
    # PageRank formula: PR(A) = (1-d)/N + d * sum(PR(B)/L(B)) for all pages B pointing to A
    # In matrix form: new_pagerank = (1-d)/N + d * transition_matrix.T @ pagerank
    # new_pagerank = np.full(num_nodes, (1 - damping_factor) / num_nodes) + \
    #                    damping_factor * np.dot(pagerank, transition_matrix) # Corrected matrix multiplication order
    new_pagerank_scores = (1 - d) / num_nodes + d * transition_matrix.T @ pagerank_scores
    # Check for convergence
    if np.linalg.norm(new_pagerank_scores - pagerank_scores, ord=1) < tolerance:
            print(f"PageRank converged after {iteration + 1} iterations.")
            break
    # print(f'Interation {iteration+1}')
    # print(new_pagerank)
    pagerank_scores = new_pagerank_scores

  return pagerank_scores
pagerank_scores = calculate_pagerank(connection_matrix)
# Print the PageRank scores
# print("PageRank Scores:")
# for i, score in enumerate(pagerank_scores):
#     print(f"Sentence ID {i}: {score:.4f} - {sentences_dict[i]['sentence_text']}")

# %% [markdown]
# Get the 10% highest score sentences to create a summary

# %%
# Get the 10% highest score sentences to create a summary
summary_sentences = sorted(range(len(pagerank_scores)), key=lambda i: pagerank_scores[i], reverse=True)[:int(0.1 * len(pagerank_scores))]
# print length of summary sentences
print(f"Number of summary sentences: {len(summary_sentences)}")

# print("Summary Sentences:")
# for i in summary_sentences:
#     print(f"Sentence ID {i}: {pagerank_scores[i]:.8f} - {sentences_dict[i]['sentence_text']}")
# summary = [sentence_dict[i]['sentence_text'] for i in summary_sentences]
# print("\nSummary Sentences:")
# for sentence in summary:
#     print(sentence)
# Out:
# Number of summary sentences: 15

# %%
# Create output directory if it doesn't exist
output_dir = 'output'
os.makedirs(output_dir, exist_ok=True)

# Get the input file name without the extension
input_filename = os.path.splitext(os.path.basename(file_path))[0]

# Define the output file path
output_file_path = os.path.join(output_dir, f'{input_filename}_cosine')

# Write the top sentences to the output file in the desired format
with open(output_file_path, 'w') as outfile:
    for sentence_id in summary_sentences:
        doc_id = sentences_dict[sentence_id]['doc_id']
        wdcount = sentences_dict[sentence_id]['wdcount']
        num = sentences_dict[sentence_id]['num']
        sentence_text = sentences_dict[sentence_id]['sentence_text']
        # Reconstruct the original sentence tag format
        outfile.write(f'<s doc_id="{doc_id}" num="{num}" wdcount="{wdcount}"> {sentence_text}</s>\n')

print(f"\nTop 10% sentences written to {output_file_path}")
# Out:
# Top 10% sentences written to output/d113h_cosine

# %%
# Evaluate the result with the summay file has given in DUC_SUM folder

preference_sum_path = "DUC_SUM/d113h"  
with open(preference_sum_path, "r", encoding="utf-8") as file:
    preference_sum_file = file.read()

preference_sum_dict = parse_doc(preference_sum_file)
print("Preference Summary Sentences:")
for sid, metadata in preference_sum_dict.items():
    print(f"Sentence ID: {sid}, Metadata: {metadata}")
# Out:
# Preference Summary Sentences:
# Sentence ID: 0, Metadata: {'doc_id': 'FT931-3664', 'num': '4', 'wdcount': 23, 'sentence_text': "FT 15 MAR 93 / Bombay stays calm in the face of horror: The city seems determined to put Friday's outrage behind it"}
# Sentence ID: 1, Metadata: {'doc_id': 'FT931-3764', 'num': '6', 'wdcount': 31, 'sentence_text': 'THE INDIAN government flew federal paramilitary troops into Bombay last night after more than a dozen bombs exploded in the city, killing about 200 people and injuring more than a thousand.'}
# Sentence ID: 2, Metadata: {'doc_id': 'FT931-2858', 'num': '6', 'wdcount': 24, 'sentence_text': 'The 29-storey Jijobhoy Towers, home of the Bombay Stock Exchange, was rocked by two powerful bombs last Friday, leaving 60 dead and 200 injured.'}
# Sentence ID: 3, Metadata: {'doc_id': 'FT931-2858', 'num': '7', 'wdcount': 12, 'sentence_text': 'The market reopened on Monday in an attempt to return to normal.'}
# Sentence ID: 4, Metadata: {'doc_id': 'FT931-2858', 'num': '9', 'wdcount': 17, 'sentence_text': 'Dealers seemed to like this, the BSE index rising by 5.6 per cent on Monday and Tuesday.'}
# Sentence ID: 5, Metadata: {'doc_id': 'FT931-2858', 'num': '10', 'wdcount': 23, 'sentence_text': 'But another bomb blast in Calcutta triggered nervous selling yesterday, and the index came back by 50.62, or 2.1 per cent, to 2,409.23.'}
# Sentence ID: 6, Metadata: {'doc_id': 'FT931-2858', 'num': '28', 'wdcount': 32, 'sentence_text': 'The Indian stock markets have been passing through a series of crises since December, when activists of the Bhartiya Janta party pulled down the Babri mosque at Ayodhya, sparking off communal riots.'}
# Sentence ID: 7, Metadata: {'doc_id': 'FT931-2981', 'num': '16', 'wdcount': 29, 'sentence_text': 'More than 2,000 people died in riots, including over 700 in Bombay, after the razing of a mosque at Ayodhya in northern India by Hindu zealots on December 6.'}
# Sentence ID: 8, Metadata: {'doc_id': 'FT931-2858', 'num': '11', 'wdcount': 44, 'sentence_text': 'All this has taken place against a volatile background: the Bombay equity market, over the past six weeks or so, has had to contend first with unusually bullish speculation, before the national budget on February 27, and subsequently with some savage expressions of disappointment.'}
# Sentence ID: 9, Metadata: {'doc_id': 'FT931-2858', 'num': '12', 'wdcount': 18, 'sentence_text': 'Dr Manmohan Singh, the Indian finance minister, disappointed traders in the budget at the end of last month.'}
# Sentence ID: 10, Metadata: {'doc_id': 'FT931-2858', 'num': '16', 'wdcount': 28, 'sentence_text': 'He lowered the tax to 30 per cent from 65 per cent for expatriate Indians and foreign investors but for local investors it remained at 44.5 per cent.'}
# Sentence ID: 11, Metadata: {'doc_id': 'FT931-2858', 'num': '20', 'wdcount': 30, 'sentence_text': 'The relative lack of financial concessions meant that disappointed traders sold with a vengeance and, until the weekend, the market seemed bottomless as equity prices plummeted to a 13-month low.'}
# Sentence ID: 12, Metadata: {'doc_id': 'FT931-4176', 'num': '8', 'wdcount': 27, 'sentence_text': "The Sebi has accused stockbrokers of flouting the exchange's rules, including regulations on margin trading designed to limit the risk of members defaulting through excessive speculative investments."}
# Sentence ID: 13, Metadata: {'doc_id': 'FT931-3764', 'num': '12', 'wdcount': 34, 'sentence_text': 'The bombs appeared designed to stir a renewal of communal strife and to undermine efforts by the government of Mr PV Narasimha Rao to open up the economy and attract foreign investment and tourism.'}

# %%
# Get the set of (doc_id, num) for sentences in preference_sum_dict
preference_keys = set((v['doc_id'], v['num']) for v in preference_sum_dict.values())

print(f"Preference keys: {preference_keys}")  

# Count how many summary_sentences are present in preference_sum_dict by (doc_id, num)
matched = 0
for sid in summary_sentences:
    sent = sentences_dict[sid]
    # print(f"Checking sentence ID {sid}: {sent['doc_id']}, {sent['num']}, {sent['sentence_text']}")
    if (sent['doc_id'], sent['num']) in preference_keys:
        print(f"Matched: {sent['doc_id']}, {sent['num']}, {sent['sentence_text']}")
        matched += 1
# Print the number of matched sentences
print (f"Number of matched sentences: {matched}")
# Calculate recall and precision
recall_percentage = (matched / len(preference_sum_dict)) * 100 if preference_sum_dict else 0
precision_percentage = (matched / len(summary_sentences)) * 100 if summary_sentences else 0
# Print recall and precision
print(f"Recall: {recall_percentage:.2f}%")
print(f"Precision: {precision_percentage:.2f}%")
# Calculate F1 score
f1_percentage = (2 * recall_percentage * precision_percentage) / (recall_percentage + precision_percentage) if (recall_percentage + precision_percentage) > 0 else 0
print(f"F1 Score: {f1_percentage:.2f}%")
# print(f"{matched} out of {len(preference_sum_dict)} summary sentences are in the preference summary ({percentage:.2f}%)")
# Out:
# Preference keys: {('FT931-4176', '8'), ('FT931-2858', '28'), ('FT931-3664', '4'), ('FT931-3764', '12'), ('FT931-2981', '16'), ('FT931-2858', '6'), ('FT931-2858', '16'), ('FT931-2858', '20'), ('FT931-3764', '6'), ('FT931-2858', '10'), ('FT931-2858', '9'), ('FT931-2858', '7'), ('FT931-2858', '12'), ('FT931-2858', '11')}
# Matched: FT931-2858, 16, He lowered the tax to 30 per cent from 65 per cent for expatriate Indians and foreign investors but for local investors it remained at 44.5 per cent.
# Matched: FT931-2858, 12, Dr Manmohan Singh, the Indian finance minister, disappointed traders in the budget at the end of last month.
# Number of matched sentences: 2
# Recall: 14.29%
# Precision: 13.33%
# F1 Score: 13.79%
